# %%
import sys
sys.path.append("../../src")
import gaussian_systems.initial_state as inits
import numpy as np

# %%
n=2
initial_covariance = inits.thermal_vacuum_covariance(n,np.array([0.3,0.15]))
initial_mean = inits.thermal_vacuum_mean(n)

# %%
(initial_covariance, initial_mean) = inits.apply_1_mode_displacement((initial_mean, initial_covariance), 2-4j, 2)

# %%
import matplotlib.pyplot as plt
from matplotlib.

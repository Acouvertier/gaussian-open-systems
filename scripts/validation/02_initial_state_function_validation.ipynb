# %%
import sys
sys.path.append("../../src")
import numpy as np
from gaussian_systems.initial_state import GaussianCVState
import gaussian_systems.metrics as cv_metrics

# %%
n = 3

my_state = GaussianCVState.vacuum(n)
my_state.single_mode_squeeze((0.5, np.pi),1).single_mode_squeeze((0.2, 0),2)
my_state.single_mode_displacement((-4-2j),2).single_mode_displacement((1+1j),3)

# %%
my_state.plot_state()
# Out:
# <Axes: xlabel='position', ylabel='momentum'>

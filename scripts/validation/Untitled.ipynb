# %%
import sys
sys.path.append("../../src")

# %%
import gaussian_systems.conventions as cvn
import numpy as np

# %%
omega = cvn.symplectic_matrix(2)

# %%
np.all(omega.T == -omega)
# Out:
# np.True_

# %%
n = 6
sub_ids = (1,5)
k = len(sub_ids)
s_mat = cvn.selection_matrix(n,sub_ids)

# %%
s_mat.shape == (2*n,2*k)
# Out:
# True
